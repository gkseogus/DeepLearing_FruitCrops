# %%
#Import Library
import os
import shutil
import glob
import cv2
import numpy as np
import zipfile

# %%
#데이터를 배열로 초기화
#감귤 데이터셋 & 키위 데이터셋
data = {}
data['Normal'] = []
data['Ulcers'] = []
data['귤응애'] = []
data['점무늬병'] = []
data['진딧물'] = []
data['총채벌레'] = []

# %%
#Create MANDARIN File
os.mkdir('master_data_concrete')
os.mkdir('master_data_concrete/training')
os.mkdir('master_data_concrete/validation')
os.mkdir('master_data_concrete/test')

os.mkdir('master_data_concrete/training/Normal')
os.mkdir('master_data_concrete/training/Ulcers')
os.mkdir('master_data_concrete/training/귤응애')
os.mkdir('master_data_concrete/training/점무늬병')
os.mkdir('master_data_concrete/training/진딧물')
os.mkdir('master_data_concrete/training/총채벌레')

os.mkdir('master_data_concrete/validation/Normal')
os.mkdir('master_data_concrete/validation/Ulcers')
os.mkdir('master_data_concrete/validation/귤응애')
os.mkdir('master_data_concrete/validation/점무늬병')
os.mkdir('master_data_concrete/validation/진딧물')
os.mkdir('master_data_concrete/validation/총채벌레')

os.mkdir('master_data_concrete/test/Normal')
os.mkdir('master_data_concrete/test/Ulcers')
os.mkdir('master_data_concrete/test/귤응애')
os.mkdir('master_data_concrete/test/점무늬병')
os.mkdir('master_data_concrete/test/진딧물')
os.mkdir('master_data_concrete/test/총채벌레')

# %%
#HF01_00FT Data
src = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\감귤 or 키위\\Normal"
for jpgImage in glob.iglob(os.path.join(src, '*jpg')):
    data['Normal'].append(jpgImage)
print("Normal :", len(data['Normal']))

#HF01_00LF Data
src1 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\감귤 or 키위\\Ulcers"
for jpgImage in glob.iglob(os.path.join(src1, '*jpg')):
    data['Ulcers'].append(jpgImage)
print("Ulcers :", len(data['Ulcers']))

#HF01_01FT Data
src2 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\감귤 or 키위\\귤응애"
for jpgImage in glob.iglob(os.path.join(src2, '*jpg')):
    data['귤응애'].append(jpgImage)
print("귤응애 :", len(data['귤응애']))

#HF01_01LF Data
src3 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\감귤 or 키위\\점무늬병"
for jpgImage in glob.iglob(os.path.join(src3, '*jpg')):
    data['점무늬병'].append(jpgImage)
print("점무늬병 :", len(data['점무늬병']))

#HF01_02LF Data
src4 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\감귤 or 키위\진딧물"
for jpgImage in glob.iglob(os.path.join(src4, '*jpg')):
    data['진딧물'].append(jpgImage)
print("진딧물 :", len(data['진딧물']))

#HF01_03LF Data
src5 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\감귤 or 키위\총채벌레"
for jpgImage in glob.iglob(os.path.join(src5, '*jpg')):
    data['총채벌레'].append(jpgImage)
print("총채벌레 :", len(data['총채벌레']))
# Out:
# Normal : 4000
# Ulcers : 3000
# 귤응애 : 1000
# 점무늬병 : 1000
# 진딧물 : 1000
# 총채벌레 : 2000

# %%
#Data shuffle
from sklearn.model_selection import train_test_split
import sys
#Normal

X = data['Normal'] #Data
Y = np.zeros((len(data['Normal']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2,random_state=2359)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25,random_state=2359)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'Normal')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'Normal')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'Normal')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 2400    Y_train Label list = 2400
# X_valid Data list = 800    Y_valid Label list = 800
# X_test Data list = 800    Y_test Label list = 800
# ...
#   0%|          | 0/800 [00:00<?, ?it/s]

# %%
#Ulcers 

X = data['Ulcers'] #Data
Y = np.zeros((len(data['Ulcers']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2,random_state=2359)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25,random_state=2359)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'Ulcers')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'Ulcers')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'Ulcers')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 1800    Y_train Label list = 1800
# X_valid Data list = 600    Y_valid Label list = 600
# X_test Data list = 600    Y_test Label list = 600
# ...
#   0%|          | 0/600 [00:00<?, ?it/s]

# %%
#귤응애 

X = data['귤응애'] #Data
Y = np.zeros((len(data['귤응애']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2,random_state=2359)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25,random_state=2359)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', '귤응애')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', '귤응애')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', '귤응애')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#점무늬병 

X = data['점무늬병'] #Data
Y = np.zeros((len(data['점무늬병']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2,random_state=2359)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25,random_state=2359)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', '점무늬병')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', '점무늬병')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', '점무늬병')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#진딧물 

X = data['진딧물'] #Data
Y = np.zeros((len(data['진딧물']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2,random_state=2359)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25,random_state=2359)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', '진딧물')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', '진딧물')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', '진딧물')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#총채벌레 

X = data['총채벌레'] #Data
Y = np.zeros((len(data['총채벌레']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2,random_state=2359)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25,random_state=2359)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', '총채벌레')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', '총채벌레')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', '총채벌레')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 1200    Y_train Label list = 1200
# X_valid Data list = 400    Y_valid Label list = 400
# X_test Data list = 400    Y_test Label list = 400
# ...
#   0%|          | 0/400 [00:00<?, ?it/s]

# %%
base_dest = 'master_data_concrete'
dest = os.path.join(base_dest, 'training','총채벌레')
dest
# Out:
# 'master_data_concrete\\training\\총채벌레'

# %%
#Model Library
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,BatchNormalization
from keras.callbacks  import EarlyStopping, LambdaCallback
from keras.layers import Activation, Dropout,Input, Flatten, Dense
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
import keras
import tensorflow as tf
import os
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
local_weights_file = 'C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'

pre_trained_model = InceptionV3(input_shape=(224, 224, 3),
                              include_top=False,
                              weights=None)

pre_trained_model.load_weights(local_weights_file)

for layer in pre_trained_model.layers:
  layer.trainable = False

pre_trained_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_376 (Conv2D)            (None, 111, 111, 32  864         ['input_5[0][0]']
#                                 )
#
#  batch_normalization_376 (Batch  (None, 111, 111, 32  96         ['conv2d_376[0][0]']
#  Normalization)                 )
#
#  activation_376 (Activation)    (None, 111, 111, 32  0           ['batch_normalization_376[0][0]']
#                                 )
#
#  conv2d_377 (Conv2D)            (None, 109, 109, 32  9216        ['activation_376[0][0]']
#                                 )
#
#  batch_normalization_377 (Batch  (None, 109, 109, 32  96         ['conv2d_377[0][0]']
#  Normalization)                 )
#
# ...

# %%
last_layer = pre_trained_model.get_layer('mixed8')
print('last layer output shape: ', last_layer.output.shape)
last_output = last_layer.output
# Out:
# last layer output shape:  (None, 5, 5, 1280)

# %%
x = layers.Flatten()(last_output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dense(6, activation='softmax')(x)

model = Model(pre_trained_model.input, x)
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_376 (Conv2D)            (None, 111, 111, 32  864         ['input_5[0][0]']
#                                 )
#
#  batch_normalization_376 (Batch  (None, 111, 111, 32  96         ['conv2d_376[0][0]']
#  Normalization)                 )
#
#  activation_376 (Activation)    (None, 111, 111, 32  0           ['batch_normalization_376[0][0]']
#                                 )
#
#  conv2d_377 (Conv2D)            (None, 109, 109, 32  9216        ['activation_376[0][0]']
#                                 )
#
#  batch_normalization_377 (Batch  (None, 109, 109, 32  96         ['conv2d_377[0][0]']
#  Normalization)                 )
#
# ...

# %%
from keras.preprocessing.image import ImageDataGenerator

batch_size = 32
epochs = 150

#스케일 조정 및 과적합 방지
train_datagen = ImageDataGenerator (
        rescale=1./255, 
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

#validation,test에 사용할 확장구성
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

#train, validation, test 모든 이미지 크기 = 224*224
train_generator = train_datagen.flow_from_directory(
        'master_data_concrete/training',  
        target_size=(224, 224), 
        batch_size=batch_size,
        shuffle=True,
        #color_mode='grayscale',
        class_mode='categorical')   #categorical_crossentropy loss를 사용하기 위한 categorical label

#검증 데이터
validation_generator = validation_datagen.flow_from_directory(
        'master_data_concrete/validation',
        target_size=(224, 224),
        batch_size=batch_size,
        shuffle=True,
        #color_mode='grayscale',
        class_mode='categorical')

#테스트 데이터
test_generator = test_datagen.flow_from_directory(
       'master_data_concrete/test',
       target_size=(224, 224),
       batch_size=batch_size,
       #color_mode='grayscale',
       class_mode='categorical')
# Out:
# Found 7200 images belonging to 6 classes.
# Found 2400 images belonging to 6 classes.
# Found 2400 images belonging to 6 classes.

# %%
#만약 overfitting, underfitting 을 일으키면 EarlyStopping을 쓰기 위한 코드  or callback 함수 적용
#patience가 15면 validation score가 15회 이상 개선이 없을때 훈련을 멈춘다

from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_accuracy', patience=30, min_delta=0.005)

# %%
#Model Learning
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) #rmsprop or adam or sgd , accuracy or f1-score  (positive와 negative의 데이터 값 차이가 높을 경우)
history = model.fit_generator(
        train_generator,
        epochs=epochs,
        validation_data=validation_generator
        ,callbacks=[es])
# Out:
# C:\Users\fbznf\AppData\Local\Temp/ipykernel_1528/2462689898.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/150
# 225/225 [==============================] - 297s 1s/step - loss: 2.1710 - accuracy: 0.5922 - val_loss: 0.7472 - val_accuracy: 0.6967
# Epoch 2/150
# 225/225 [==============================] - 290s 1s/step - loss: 0.6705 - accuracy: 0.7322 - val_loss: 0.8706 - val_accuracy: 0.6596
# Epoch 3/150
# 225/225 [==============================] - 289s 1s/step - loss: 0.6178 - accuracy: 0.7510 - val_loss: 0.6062 - val_accuracy: 0.7558
# Epoch 4/150
# 225/225 [==============================] - 289s 1s/step - loss: 0.5029 - accuracy: 0.7986 - val_loss: 0.6058 - val_accuracy: 0.7529
# Epoch 5/150
# 225/225 [==============================] - 289s 1s/step - loss: 0.4684 - accuracy: 0.8118 - val_loss: 0.5392 - val_accuracy: 0.7858
# Epoch 6/150
# ...

# %%
#훈련 및 검증 정확도 시각화
#학습 정확성 값과 검증 정확성 값
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')
plt.show()

# 학습 손실 값과 검증 손실 값
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')
plt.show()

# %%
#model test
loss, accuracy = model.evaluate_generator(test_generator)
print('test loss: ', loss, '\ntest accuracy: ', accuracy)
# Out:
# C:\Users\fbznf\AppData\Local\Temp/ipykernel_1528/2074993950.py:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   loss, accuracy = model.evaluate_generator(test_generator)
# test loss:  1.1145715713500977
# test accuracy:  0.8033333420753479

# %%
from keras.models import load_model

model.save('InceptionV3_model')
# Out:
# INFO:tensorflow:Assets written to: InceptionV3_model\assets
