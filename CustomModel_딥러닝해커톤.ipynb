# %%
#Import Library
import os
import shutil
import glob
import cv2
import numpy as np
import zipfile

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7715042517342720704
# xla_global_id: -1
# ]

# %%
# %cd C:\Users\fbznf\Desktop\DeepLearning_project\DeepLearing_FruitCrops\01_mandarin_dataset\HF01_00FT
# Out:
# C:\Users\fbznf\Desktop\DeepLearning_project\DeepLearing_FruitCrops\01_mandarin_dataset\HF01_00FT

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 34AE-E393
#
#  C:\Users\fbznf\Desktop\DeepLearning_project\DeepLearing_FruitCrops\01_mandarin_dataset\HF01_00FT 디렉터리
#
# 2021-12-07  오후 11:29    <DIR>          .
# 2021-12-07  오후 11:29    <DIR>          ..
# 2021-08-24  오전 10:35           500,791 HF01_00FT_000001.jpg
# 2021-10-31  오후 10:15               969 HF01_00FT_000001.json
# 2021-08-24  오전 10:35           498,270 HF01_00FT_000002.jpg
# 2021-10-31  오후 10:15               969 HF01_00FT_000002.json
# 2021-08-24  오전 10:35           486,693 HF01_00FT_000003.jpg
# 2021-10-31  오후 10:15               969 HF01_00FT_000003.json
# 2021-08-24  오전 10:35           525,379 HF01_00FT_000004.jpg
# 2021-10-31  오후 10:15               969 HF01_00FT_000004.json
# 2021-08-24  오전 10:35           512,473 HF01_00FT_000005.jpg
# 2021-10-31  오후 10:15               969 HF01_00FT_000005.json
# 2021-08-24  오전 10:35           525,001 HF01_00FT_000006.jpg
# 2021-10-31  오후 10:15               969 HF01_00FT_000006.json
# ...

# %%
#데이터를 배열로 초기화
#감귤 데이터셋
data = {}
data['HF01_00FT'] = []
data['HF01_00LF'] = []
data['HF01_01FT'] = []
data['HF01_01LF'] = []
data['HF01_02LF'] = []
data['HF01_03LF'] = []

# %%
#HF01_00FT Data
src = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\01_mandarin_dataset\\HF01_00FT\\"
for jpgImage in glob.iglob(os.path.join(src, '*jpg')):
    data['HF01_00FT'].append(jpgImage)
print("HF01_00FT :", len(data['HF01_00FT']))

#HF01_00LF Data
src1 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\01_mandarin_dataset\\HF01_00LF\\"
for jpgImage in glob.iglob(os.path.join(src1, '*jpg')):
    data['HF01_00LF'].append(jpgImage)
print("HF01_00LF :", len(data['HF01_00LF']))

#HF01_01FT Data
src2 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\01_mandarin_dataset\\HF01_01FT\\"
for jpgImage in glob.iglob(os.path.join(src2, '*jpg')):
    data['HF01_01FT'].append(jpgImage)
print("HF01_01FT :", len(data['HF01_01FT']))

#HF01_01LF Data
src3 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\01_mandarin_dataset\\HF01_01LF\\"
for jpgImage in glob.iglob(os.path.join(src3, '*jpg')):
    data['HF01_01LF'].append(jpgImage)
print("HF01_01LF :", len(data['HF01_01LF']))

#HF01_02LF Data
src4 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\01_mandarin_dataset\\HF01_02LF\\"
for jpgImage in glob.iglob(os.path.join(src4, '*jpg')):
    data['HF01_02LF'].append(jpgImage)
print("HF01_02LF :", len(data['HF01_02LF']))

#HF01_03LF Data
src5 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\01_mandarin_dataset\\HF01_03LF\\"
for jpgImage in glob.iglob(os.path.join(src5, '*jpg')):
    data['HF01_03LF'].append(jpgImage)
print("HF01_03LF :", len(data['HF01_03LF']))
# Out:
# HF01_00FT : 1000
# HF01_00LF : 1000
# HF01_01FT : 1000
# HF01_01LF : 1000
# HF01_02LF : 1000
# HF01_03LF : 1000

# %%
#Create MANDARIN File
os.mkdir('master_data_concrete')
os.mkdir('master_data_concrete/training')
os.mkdir('master_data_concrete/validation')
os.mkdir('master_data_concrete/test')

os.mkdir('master_data_concrete/training/HF01_00FT')
os.mkdir('master_data_concrete/training/HF01_00LF')
os.mkdir('master_data_concrete/training/HF01_01FT')
os.mkdir('master_data_concrete/training/HF01_01LF')
os.mkdir('master_data_concrete/training/HF01_02LF')
os.mkdir('master_data_concrete/training/HF01_03LF')

os.mkdir('master_data_concrete/validation/HF01_00FT')
os.mkdir('master_data_concrete/validation/HF01_00LF')
os.mkdir('master_data_concrete/validation/HF01_01FT')
os.mkdir('master_data_concrete/validation/HF01_01LF')
os.mkdir('master_data_concrete/validation/HF01_02LF')
os.mkdir('master_data_concrete/validation/HF01_03LF')

os.mkdir('master_data_concrete/test/HF01_00FT')
os.mkdir('master_data_concrete/test/HF01_00LF')
os.mkdir('master_data_concrete/test/HF01_01FT')
os.mkdir('master_data_concrete/test/HF01_01LF')
os.mkdir('master_data_concrete/test/HF01_02LF')
os.mkdir('master_data_concrete/test/HF01_03LF')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9836/1083737604.py in <module>
#       1 #Create MANDARIN File
# ----> 2 os.mkdir('master_data_concrete')
#       3 os.mkdir('master_data_concrete/training')
#       4 os.mkdir('master_data_concrete/validation')
#       5 os.mkdir('master_data_concrete/test')
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'master_data_concrete'

# %%
#Data shuffle
from sklearn.model_selection import train_test_split
import sys
#HF01_00FT

X = data['HF01_00FT'] #Data
Y = np.zeros((len(data['HF01_00FT']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'HF01_00FT')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'HF01_00FT')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'HF01_00FT')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#HF01_00LF 

X = data['HF01_00LF'] #Data
Y = np.zeros((len(data['HF01_00LF']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'HF01_00LF')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'HF01_00LF')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'HF01_00LF')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#HF01_01FT 

X = data['HF01_01FT'] #Data
Y = np.zeros((len(data['HF01_01FT']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'HF01_01FT')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'HF01_01FT')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'HF01_01FT')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#HF01_01LF 

X = data['HF01_01LF'] #Data
Y = np.zeros((len(data['HF01_01LF']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'HF01_01LF')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'HF01_01LF')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'HF01_01LF')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#HF01_02LF 

X = data['HF01_02LF'] #Data
Y = np.zeros((len(data['HF01_02LF']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'HF01_02LF')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'HF01_02LF')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'HF01_02LF')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#HF01_03LF 

X = data['HF01_03LF'] #Data
Y = np.zeros((len(data['HF01_03LF']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'HF01_03LF')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'HF01_03LF')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'HF01_03LF')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#데이터를 배열로 초기화
#키위 데이터셋
data = {}
data['HF02_00FT'] = []
data['HF02_00LF'] = []
data['HF02_01LF'] = []
data['HF02_04LF'] = []
data['HF02_06FT'] = []
data['HF02_06LF'] = []

# %%
#Create KIWI File
os.mkdir('master_data_concrete/training/HF02_00FT')
os.mkdir('master_data_concrete/training/HF02_00LF')
os.mkdir('master_data_concrete/training/HF02_01LF')
os.mkdir('master_data_concrete/training/HF02_04LF')
os.mkdir('master_data_concrete/training/HF02_06FT')
os.mkdir('master_data_concrete/training/HF02_06LF')

os.mkdir('master_data_concrete/validation/HF02_00FT')
os.mkdir('master_data_concrete/validation/HF02_00LF')
os.mkdir('master_data_concrete/validation/HF02_01LF')
os.mkdir('master_data_concrete/validation/HF02_04LF')
os.mkdir('master_data_concrete/validation/HF02_06FT')
os.mkdir('master_data_concrete/validation/HF02_06LF')

os.mkdir('master_data_concrete/test/HF02_00FT')
os.mkdir('master_data_concrete/test/HF02_00LF')
os.mkdir('master_data_concrete/test/HF02_01LF')
os.mkdir('master_data_concrete/test/HF02_04LF')
os.mkdir('master_data_concrete/test/HF02_06FT')
os.mkdir('master_data_concrete/test/HF02_06LF')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9836/64135905.py in <module>
#       1 #Create KIWI File
# ----> 2 os.mkdir('master_data_concrete/training/HF02_00FT')
#       3 os.mkdir('master_data_concrete/training/HF02_00LF')
#       4 os.mkdir('master_data_concrete/training/HF02_01LF')
#       5 os.mkdir('master_data_concrete/training/HF02_04LF')
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'master_data_concrete/training/HF02_00FT'

# %%
#HF01_00FT Data
src = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\02_kiwi_dataset\\HF02_00FT\\"
for jpgImage in glob.iglob(os.path.join(src, '*jpg')):
    data['HF02_00FT'].append(jpgImage)
print("HF02_00FT :", len(data['HF02_00FT']))

#HF01_00FT Data
src1 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\02_kiwi_dataset\\HF02_00LF\\"
for jpgImage in glob.iglob(os.path.join(src1, '*jpg')):
    data['HF02_00LF'].append(jpgImage)
print("HF02_00LF :", len(data['HF02_00LF']))

#HF01_00FT Data
src2 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\02_kiwi_dataset\\HF02_01LF\\"
for jpgImage in glob.iglob(os.path.join(src2, '*jpg')):
    data['HF02_01LF'].append(jpgImage)
print("HF02_01LF :", len(data['HF02_01LF']))

#HF01_00FT Data
src3 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\02_kiwi_dataset\\HF02_04LF\\"
for jpgImage in glob.iglob(os.path.join(src3, '*jpg')):
    data['HF02_04LF'].append(jpgImage)
print("HF02_04LF :", len(data['HF02_04LF']))

#HF01_00FT Data
src4 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\02_kiwi_dataset\\HF02_06FT\\"
for jpgImage in glob.iglob(os.path.join(src4, '*jpg')):
    data['HF02_06FT'].append(jpgImage)
print("HF02_06FT :", len(data['HF02_06FT']))

#HF01_00FT Data
src5 = "C:\\Users\\fbznf\\Desktop\\DeepLearning_project\\DeepLearing_FruitCrops\\02_kiwi_dataset\\HF02_06LF\\"
for jpgImage in glob.iglob(os.path.join(src5, '*jpg')):
    data['HF02_06LF'].append(jpgImage)
print("HF02_06LF :", len(data['HF02_06LF']))
# Out:
# HF02_00FT : 1000
# HF02_00LF : 1000
# HF02_01LF : 1000
# HF02_04LF : 1000
# HF02_06FT : 1000
# HF02_06LF : 1000

# %%
#HF02_00FT  

X = data['HF02_00FT'] #Data
Y = np.zeros((len(data['HF02_00FT']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'HF02_00FT')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'HF02_00FT')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'HF02_00FT')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#HF02_00LF  

X = data['HF02_00LF'] #Data
Y = np.zeros((len(data['HF02_00LF']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'HF02_00LF')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'HF02_00LF')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'HF02_00LF')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#HF02_01LF  

X = data['HF02_01LF'] #Data
Y = np.zeros((len(data['HF02_01LF']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'HF02_01LF')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'HF02_01LF')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'HF02_01LF')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#HF02_04LF  

X = data['HF02_04LF'] #Data
Y = np.zeros((len(data['HF02_04LF']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'HF02_04LF')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'HF02_04LF')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'HF02_04LF')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#HF02_06FT  

X = data['HF02_06FT'] #Data
Y = np.zeros((len(data['HF02_06FT']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'HF02_06FT')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'HF02_06FT')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'HF02_06FT')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
#HF02_06LF  

X = data['HF02_06LF'] #Data
Y = np.zeros((len(data['HF02_06LF']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.25)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))

#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', 'HF02_06LF')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', 'HF02_06LF')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', 'HF02_06LF')
        shutil.copy(image, dest)
# Out:
# X_train Data list = 600    Y_train Label list = 600
# X_valid Data list = 200    Y_valid Label list = 200
# X_test Data list = 200    Y_test Label list = 200
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
base_dest = 'master_data_concrete'
dest = os.path.join(base_dest, 'training','HF02_06LF')
dest
# Out:
# 'master_data_concrete\\training\\HF02_06LF'

# %%
#Model Library
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,BatchNormalization
from keras.callbacks  import EarlyStopping, LambdaCallback
from keras.layers import Activation, Dropout,Input, Flatten, Dense
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator

# %%
#Convolutional Layer
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3)))  #size 150
model.add(BatchNormalization(axis=-1)) #Normalize Batch
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))

model.add(Conv2D(256, (3, 3)))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))


#Output Layer
model.add(Flatten())  #3D를 1D로 벡터 변환
model.add(Dense(128))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.4))

model.add(Dense(64))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(12)) 
model.add(BatchNormalization(axis=-1))
model.add(Activation('softmax'))  #or model.add(Activation('softmax')) // two output softmax == one output sigmoid

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_14 (Conv2D)          (None, 148, 148, 32)      896
#
#  batch_normalization_22 (Bat  (None, 148, 148, 32)     128
#  chNormalization)
#
#  activation_22 (Activation)  (None, 148, 148, 32)      0
#
#  max_pooling2d_8 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 72, 72, 64)        18496
#
#  batch_normalization_23 (Bat  (None, 72, 72, 64)       256
#  chNormalization)
#
#  activation_23 (Activation)  (None, 72, 72, 64)        0
#
#  max_pooling2d_9 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 34, 34, 128)       73856
#
#  batch_normalization_24 (Bat  (None, 34, 34, 128)      512
#  chNormalization)
#
#  activation_24 (Activation)  (None, 34, 34, 128)       0
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 256)       295168
#
# ...

# %%
# from tensorflow.compat.v1 import ConfigProto
# from tensorflow.compat.v1 import InteractiveSession

# config = ConfigProto()
# config.gpu_options.allow_growth = True
# session = InteractiveSession(config=config)

# %%
#tf.keras.preprocessing.image_dataset_from_directory(
#    directory, labels='inferred', label_mode='int',
 #   class_names=None, color_mode='rgb', batch_size=32, image_size=(256,
 #   256), shuffle=True, seed=None, validation_split=None, subset=None,
 #   interpolation='bilinear', follow_links=False, smart_resize=False
#)

# %%
from keras.preprocessing.image import ImageDataGenerator

batch_size = 25
epochs = 100

#스케일 조정 및 과적합 방지
train_datagen = ImageDataGenerator (
        rescale=1./255, 
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

#validation,test에 사용할 확장구성
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

#train, validation, test 모든 이미지 크기 = 150*150
train_generator = train_datagen.flow_from_directory(
        'master_data_concrete/training',  
        target_size=(150, 150), 
        batch_size=batch_size,
        shuffle=True,
        #color_mode='grayscale',
        class_mode='categorical')   #categorical_crossentropy loss를 사용하기 위한 categorical label

#검증 데이터
validation_generator = validation_datagen.flow_from_directory(
        'master_data_concrete/validation',
        target_size=(150, 150),
        batch_size=batch_size,
        shuffle=True,
        #color_mode='grayscale',
        class_mode='categorical')

#테스트 데이터
test_generator = test_datagen.flow_from_directory(
       'master_data_concrete/test',
       target_size=(150, 150),
       batch_size=batch_size,
       #color_mode='grayscale',
       class_mode='categorical')
# Out:
# Found 7674 images belonging to 12 classes.
# Found 2712 images belonging to 12 classes.
# Found 2730 images belonging to 12 classes.

# %%
4#만약 overfitting, underfitting 을 일으키면 EarlyStopping을 쓰기 위한 코드  or callback 함수 적용
#patience가 5면 validation score가 5회 이상 개선이 없을때 훈련을 멈춘다

from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_accuracy', patience=5, min_delta=0.005)

# %%
#Model Learning
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) #rmsprop or adam or sgd , accuracy or f1-score  (positive와 negative의 데이터 값 차이가 높을 경우)
history = model.fit_generator(
        train_generator,
        epochs=epochs,
        validation_data=validation_generator)
        #,callbacks=[es])
# Out:
# C:\Users\fbznf\AppData\Local\Temp/ipykernel_9836/539865971.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/100
# 307/307 [==============================] - 318s 1s/step - loss: 1.6484 - accuracy: 0.4027 - val_loss: 2.2575 - val_accuracy: 0.2504
# Epoch 2/100
# 307/307 [==============================] - 307s 1s/step - loss: 1.3541 - accuracy: 0.5046 - val_loss: 2.3342 - val_accuracy: 0.1892
# Epoch 3/100
# 307/307 [==============================] - 310s 1s/step - loss: 1.2365 - accuracy: 0.5465 - val_loss: 1.4810 - val_accuracy: 0.4163
# Epoch 4/100
# 307/307 [==============================] - 305s 993ms/step - loss: 1.1532 - accuracy: 0.5735 - val_loss: 1.2944 - val_accuracy: 0.4720
# Epoch 5/100
# 307/307 [==============================] - 306s 996ms/step - loss: 1.1038 - accuracy: 0.5893 - val_loss: 1.4005 - val_accuracy: 0.4631
# ...

# %%
#훈련 및 검증 정확도 시각화
#학습 정확성 값과 검증 정확성 값
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')
plt.show()

# 학습 손실 값과 검증 손실 값
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')
plt.show()

# %%
#model test
loss, accuracy = model.evaluate_generator(test_generator)
print('test loss: ', loss, '\ntest accuracy: ', accuracy)
